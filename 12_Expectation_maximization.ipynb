# %% [markdown]
# ## Algoritmo Expectation Maximization
# ##### por  Javier Vallejos

# %% [markdown]
# ### 1. Descripción

# %% [markdown]
# El algoritmo de maximización de expectativas (EM) es una técnica estadística que se utiliza para agrupar datos, particularmente en situaciones donde los puntos de datos no se pueden asignar fácilmente a grupos distintos. Es un algoritmo iterativo que busca encontrar las estimaciones de máxima verosimilitud de los parámetros del grupo, como medias y covarianzas, al mismo tiempo que estima la probabilidad de que cada punto de datos pertenezca a cada grupo.
#
# A continuación se ofrece una breve descripción general de cómo funciona el algoritmo EM para la agrupación en clústeres:
#
# 1. **Inicialización:** Comience inicializando los parámetros para cada grupo, generalmente seleccionando valores iniciales aleatoriamente o utilizando algún otro método heurístico.
#
# 2. **Paso de expectativa (paso E):** En este paso, el algoritmo asigna a cada punto de datos una probabilidad de pertenecer a cada grupo en función de las estimaciones de los parámetros actuales. Calcula la probabilidad de cada punto de datos dados los parámetros del grupo actual y pondera estas probabilidades utilizando las probabilidades anteriores de los grupos.
#
# 3. **Paso de maximización (paso M):** En este paso, el algoritmo actualiza los parámetros del clúster para maximizar la probabilidad logarítmica esperada de los datos. Esto implica volver a estimar las medias, las covarianzas y los antecedentes del grupo en función de las probabilidades asignadas en el paso E.
#
# 4. **Iteración:** Los pasos 2 y 3 se repiten iterativamente hasta la convergencia, lo que significa que las estimaciones de los parámetros ya no cambian significativamente o se cumple un criterio de parada predefinido.
#
# 5. **Salida:** El resultado final del algoritmo EM es un conjunto de parámetros de clúster, que se pueden utilizar para asignar puntos de datos a los clústeres en función de sus probabilidades más altas.
#
# EM es particularmente útil cuando se trata de datos mixtos, donde los puntos de datos pueden generarse a partir de una combinación de diferentes distribuciones subyacentes o cuando el número de grupos no se conoce de antemano. Proporciona un marco probabilístico para la agrupación que puede manejar la incertidumbre en las asignaciones de agrupaciones y se usa ampliamente en diversos campos, incluido el aprendizaje automático, el procesamiento de imágenes y la biología.

# %% [markdown]
# ### 2. Birtex y Referencias

# %% [markdown]
# * @article{bradley1998scaling,
#   title={Scaling EM (expectation-maximization) clustering to large databases},
#   author={Bradley, Paul S and Fayyad, Usama and Reina, Cory and others},
#   journal={Microsoft Research},
#   pages={0--25},
#   year={1998},
#   publisher={Citeseer}
# }
# * @article{jung2014clustering,
#   title={Clustering performance comparison using K-means and expectation maximization algorithms},
#   author={Jung, Yong Gyu and Kang, Min Soo and Heo, Jun},
#   journal={Biotechnology \& Biotechnological Equipment},
#   volume={28},
#   number={sup1},
#   pages={S44--S48},
#   year={2014},
#   publisher={Taylor \& Francis}
# }
# * https://www.kaggle.com/code/azminetoushikwasi/different-clustering-techniques-and-algorithms
# * chatGPT

# %% [markdown]
# ### 3. Tipo de Modelo

# %% [markdown]
# El algoritmo de Maximización de Expectativas (EM) generalmente se considera:
#
# 1. **Supervisado o no supervisado:** EM es principalmente un algoritmo de aprendizaje **no supervisado**. Se utiliza para tareas de agrupación y estimación de densidad, donde el objetivo es encontrar patrones o estructuras subyacentes en los datos sin ninguna información objetivo etiquetada.
#
# 2. **Aprendizaje por lotes o en línea:** EM generalmente se usa en una configuración de aprendizaje **por lotes**, donde procesa todo el conjunto de datos en cada iteración. Sin embargo, existen variantes de EM, como el EM en línea o el EM estocástico, que adaptan el algoritmo para el aprendizaje en línea actualizando los parámetros del modelo de forma incremental a medida que llegan nuevos puntos de datos.
#
# 3. **Basado en instancias o basado en modelos:** EM es un algoritmo **basado en modelos**. Se supone que los puntos de datos se generan a partir de un modelo probabilístico, a menudo representado por una mezcla de distribuciones de probabilidad (por ejemplo, modelos de mezcla gaussiana en agrupación). EM refina iterativamente los parámetros del modelo para que se ajusten mejor a los datos observados.
#
# 4. **Paramétrico o no paramétrico:** EM generalmente se considera un algoritmo **paramétrico**. Se supone que la distribución de datos subyacente puede representarse mediante un modelo paramétrico específico (por ejemplo, distribuciones gaussianas en modelos de mezcla gaussiana). Los métodos no paramétricos, por otro lado, no hacen suposiciones explícitas sobre la forma funcional de la distribución de datos y pueden adaptarse más flexiblemente a patrones de datos complejos. La naturaleza paramétrica de EM significa que asume una forma específica para la distribución de datos y puede no ser tan flexible como los métodos no paramétricos como la estimación de la densidad del núcleo o la agrupación jerárquica. Sin embargo, existen variaciones de EM, como los modelos de mezcla finita, que pueden verse como un compromiso entre los enfoques paramétricos y no paramétricos, ya que permiten un número finito de componentes (grupos) en la mezcla.

# %% [markdown]
# ### 4. Algoritmos de entrenamiento

# %% [markdown]
# Ciertamente, profundicemos en más detalles sobre el algoritmo de entrenamiento para el algoritmo de Maximización de Expectativas (EM), particularmente en el contexto de agrupación utilizando Modelos de Mezcla Gaussianos (GMM). EM es un algoritmo de optimización iterativo utilizado para estimar los parámetros de un GMM cuando los datos pueden generarse a partir de una combinación de distribuciones gaussianas. A continuación se detallan los pasos clave involucrados en el algoritmo de entrenamiento:
#
# 1. **Inicialización:**
#     - Inicializar los parámetros de las componentes gaussianas. Las inicializaciones comunes incluyen la inicialización aleatoria, la agrupación de K-medias para obtener medias iniciales y el uso de matrices de covarianza diagonales para simplificar.
#     - Inicializar los coeficientes de mezcla (probabilidades previas) para cada componente, normalmente con valores iguales si no hay información previa disponible.
#
# 2. **Paso de expectativa (paso E):**
#     - Calcular la responsabilidad de cada componente gaussiano para cada punto de datos. La responsabilidad representa la probabilidad de que un punto de datos pertenezca a un componente específico.
#     - Utilizar el teorema de Bayes para calcular estas responsabilidades, teniendo en cuenta las estimaciones de los parámetros actuales (medias, covarianzas y coeficientes de mezcla).
#
# 3. **Paso de maximización (paso M):**
#     - Actualizar los parámetros de cada componente gaussiano en función de las responsabilidades calculadas en el E-step.
#     - Actualizar las medias, covarianzas y coeficientes de mezcla para maximizar la probabilidad logarítmica esperada de los datos.
#     - Las fórmulas para actualizar estos parámetros se derivan de maximizar la probabilidad logarítmica de los datos, dadas las responsabilidades.
#
# 4. **Verificación de convergencia:**
#     - Verificar la convergencia evaluando si las estimaciones de los parámetros se han estabilizado o si se ha cumplido un criterio de convergencia predefinido (por ejemplo, cambio en la probabilidad logarítmica, número máximo de iteraciones).
#     - Si no se alcanza la convergencia, regrese al paso E y repita el proceso.
#
# 5. **Salida:**
#     - Una vez que el algoritmo converge, los parámetros finales estimados (medias, covarianzas y coeficientes de mezcla) representan los componentes gaussianos que mejor describen la distribución de los datos.
#     - Estos parámetros se pueden utilizar para la estimación de agrupamiento o densidad.
#
# 6. **Estrategias de inicialización y convergencia:**
#     - La elección de los criterios de inicialización y convergencia puede afectar significativamente el desempeño de los ME. Las estrategias comunes incluyen el uso de múltiples inicializaciones aleatorias y seleccionar la solución con la mayor probabilidad, o la inicialización con los resultados de un algoritmo de agrupamiento preliminar como K-means.
#     - La convergencia se puede monitorear rastreando el cambio en la probabilidad logarítmica o el cambio en los valores de los parámetros entre iteraciones.
#
# 7. **Manejo de matrices de covarianza singulares:**
#     - Pueden aparecer matrices de covarianza singulares durante el entrenamiento, especialmente con conjuntos de datos pequeños. Para abordar este problema, se pueden aplicar técnicas de regularización como agregar una pequeña constante a la diagonal de las matrices de covarianza (conocida como "piso de covarianza").
#
# 8. **Manejo de la estabilidad numérica:**
#     - Para evitar problemas de inestabilidad numérica cuando se trata de probabilidades muy pequeñas o matrices de covarianza casi singulares, en los cálculos se suelen utilizar probabilidades logarítmicas y determinantes logarítmicos.
#
# El algoritmo EM continúa iterando entre el paso E y el paso M hasta la convergencia o hasta que se alcanza un número máximo de iteraciones. Es importante tener en cuenta que EM es sensible a la elección de los parámetros iniciales y puede converger a un óptimo local, por lo que ejecutar el algoritmo con múltiples inicializaciones es una práctica común para encontrar una mejor solución.

# %% [markdown]
# ### 5. Supuestos y restricciones

# %% [markdown]
# El algoritmo de Maximización de Expectativas (EM) es una técnica estadística poderosa, pero viene con ciertas suposiciones y restricciones que es importante tener en cuenta al usarlo:
#
# **Supuestos:**
#
# 1. **Los datos siguen una distribución específica:** EM supone que los puntos de datos observados se generan a partir de un modelo probabilístico con una forma paramétrica específica. Por ejemplo, en el caso de los modelos de mezcla gaussiana (GMM), EM supone que los puntos de datos se generan a partir de una mezcla de distribuciones gaussianas. Esto significa que si sus datos no se ajustan a esta suposición, es posible que EM no funcione bien.
#
# 2. **Independencia de los puntos de datos:** EM supone que los puntos de datos son independientes y están distribuidos de manera idéntica (i.i.d.). Esta suposición es crucial para el cálculo de la probabilidad y las responsabilidades en el paso E. Si sus datos tienen dependencias temporales o espaciales, es posible que EM no sea la mejor opción y es posible que deba considerar otras técnicas.
#
# 3. **Disponibilidad completa de datos:** EM supone que usted tiene acceso tanto a los datos observados como a los datos completos, donde los datos completos incluyen las variables ocultas o no observadas. En muchos escenarios prácticos, los datos completos no están disponibles y es necesario diseñar cuidadosamente el algoritmo para manejar esta información faltante.
#
# 4. **Número conocido de componentes (grupos):** En el caso de modelos mixtos, EM supone que usted conoce o puede estimar el número de componentes (grupos) de antemano. Si elige una cantidad incorrecta de componentes, puede generar resultados de agrupación deficientes. Determinar el número óptimo de componentes suele ser un problema por sí solo.
#
# **Restricciones:**
#
# 1. **Óptimo local:** EM es sensible a la elección de los parámetros iniciales y puede converger a óptimos locales. Para mitigar este problema, es común ejecutar EM con múltiples inicializaciones y elegir la solución con mayor probabilidad. Sin embargo, no hay garantía de encontrar el óptimo global.
#
# 2. **Computacionalmente intensivo:** EM puede ser computacionalmente costoso, especialmente para datos de alta dimensión o cuando la cantidad de componentes es grande. El algoritmo requiere múltiples iteraciones del paso E y del paso M, lo que lo hace menos eficiente para conjuntos de datos a gran escala.
#
# 3. **Sensibilidad a la inicialización:** El rendimiento de EM puede depender en gran medida de la elección de los valores de los parámetros iniciales. Las inicializaciones deficientes pueden provocar una convergencia lenta o una convergencia a soluciones subóptimas.
#
# 4. **Supuesto de mezclas finitas:** EM supone un número finito de componentes en los modelos de mezcla. Si sus datos realmente involucran un número infinito de distribuciones o grupos subyacentes, los modelos no paramétricos como los modelos de mezcla de procesos de Dirichlet pueden ser más apropiados.
#
# 5. **Falta de solidez ante los valores atípicos:** EM puede ser sensible a los valores atípicos ya que intenta ajustar los datos según su modelo probabilístico. Los valores atípicos pueden afectar desproporcionadamente a las estimaciones de los parámetros, lo que podría dar lugar a resultados de agrupación deficientes.
#
# En resumen, si bien el algoritmo EM es una herramienta valiosa para muchas tareas estadísticas y de aprendizaje automático, no es una solución única para todos. Es esencial considerar cuidadosamente las suposiciones y limitaciones de EM en el contexto de sus datos específicos y el dominio del problema. Dependiendo de las características y objetivos de sus datos, es posible que necesite explorar métodos alternativos que se ajusten mejor a sus requisitos.

# %% [markdown]
# ### 6. Ejemplo

# %%
import numpy as np
from sklearn.mixture import GaussianMixture

# Generate synthetic data
np.random.seed(0)
n_samples = 300
mean1, cov1 = [2, 2], [[1, 0.5], [0.5, 1]]
mean2, cov2 = [8, 8], [[2, -1.5], [-1.5, 2]]
X = np.concatenate([np.random.multivariate_normal(mean1, cov1, int(n_samples / 2)),
                    np.random.multivariate_normal(mean2, cov2, int(n_samples / 2))])

# Fit a Gaussian Mixture Model using EM
n_components = 2  # Number of clusters/components
gmm = GaussianMixture(n_components=n_components, random_state=0)

# Fit the model to the data
gmm.fit(X)

# Predict cluster assignments for each data point
labels = gmm.predict(X)

# Access the estimated parameters of the GMM
print("Means:\n", gmm.means_)
print("Covariances:\n", gmm.covariances_)
print("Weights (mixing coefficients):\n", gmm.weights_)

# Visualize the clustering results
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
plt.title('GMM Clustering Results')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
# Out:
# Means:
#  [[8.11643535 7.74797173]
#  [1.98406348 2.07078515]]
# Covariances:
#  [[[ 1.95375141 -1.542297  ]
#   [-1.542297    2.10798146]]
#
#  [[ 0.95226166  0.51797018]
#   [ 0.51797018  1.06257522]]]
# Weights (mixing coefficients):
#  [0.49999961 0.50000039]
